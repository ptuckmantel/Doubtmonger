# %%
from GoogleNews import GoogleNews
from newspaper import Article
import numpy as np
import pandas as pd
import random

# %%
# Load the list of climate change denier institutions as identified by desmoblog 
# (https://www.desmogblog.com/global-warming-denier-database)
institutions = pd.read_excel('denier institutions.xlsx')['denier institutions'].tolist()

# %%
for inst in institutions:
    print(inst)
# Out:
# 55 Tufton Street
# 60 Plus Association
# Accuracy in Media
# Acton Institute
# Adam Smith Institute
# Aegis Strategic
# Africa Fighting Malaria
# African Centre for Advocacy and Human Development
# Alberta Prosperity Fund
# Alexis de Tocqueville Institution
# Alternate Solutions Institute
# America Rising LLC | PAC | America Rising Squared | Definers Public Affairs
# American Association of Blacks in Energy
# American Chemistry Council
# American Coalition for Clean Coal Electricity
# American Commitment
# American Conservative Union
# American Council for Capital Formation
# American Council on Science and Health
# American Encore
# American Energy Alliance (AEA)
# American Enterprise Institute
# American Fuel & Petrochemical Manufacturers (AFPM)
# American Future Fund
# American Institute for Economic Research
# American Legislative Exchange Council (ALEC)
# American Petroleum Institute
# American Tradition Institute
# Americans for Balanced Energy Choices
# Americans for Prosperity
# Americans for Tax Reform
# Annapolis Center for Science-Based Public Policy
# APCO Worldwide
# Atlantic Legal Foundation
# Atlas Network
# Australian APEC Study Centre
# Australian Climate Science Coalition
# Australian Environment Foundation
# Australian Libertarian Society
# Australian Taxpayers' Alliance
# Austrian Economics Center
# Ayn Rand Institute
# Beacon Center of Tennessee
# Beacon Hill Institute
# Bill of Rights Institute
# Burn More Coal
# Californians for Affordable & Reliable Energy (CARE)
# Cambridge Analytica
# Canada Action
# Canadian Association of Petroleum Producers (CAPP)
# Capital Research Center
# Carbon Sense Coalition
# Cascade Policy Institute
# Cato Institute
# Center for Accountability in Science
# Center for Energy and Economic Development
# Center for Industrial Progress
# Center for Liquefied Natural Gas (CLNG)
# Center for Organizational Research and Education (CORE)
# Center for the Defense of Free Enterprise
# Center for the Study of Carbon Dioxide and Global Change
# Center of the American Experiment
# Citizens for the Republic
# Citizens' Alliance for Responsible Energy
# Civil Society Coalition on Climate Change
# Clear Energy Alliance
# Clexit
# Climate Intelligence Foundation (CLINTEL)
# Climate Study Group
# CO2 Coalition
# Coalition for Regulatory Innovation
# Coalition to Protect Patients' Rights
# Committee for a Constructive Tomorrow (CFACT)
# Competitive Enterprise Institute
# Concerned Veterans for America
# Congress of Racial Equality (CORE)
# Consumer Action for a Strong Economy
# Consumer Choice Center
# Consumer Energy Alliance (CEA)
# Cooler Heads Coalition
# Copenhagen Consensus Center
# Cornwall Alliance for the Stewardship of Creation
# Council for a Competitive Economy
# CRC Advisors
# D. James Kennedy Ministries
# DCI Group
# Discovery Institute
# Doctors for Disaster Preparedness
# Donors Capital Fund
# Donors Trust
# Dunn's Foundation for the Advancement of Right Thinking
# Edison Electric Institute
# Energy & Environment Legal Institute
# Energy and Environment (Journal)
# Energy Equality Coalition
# Energy In Depth
# Energy4US
# Ethical Oil Institute
# European Institute for Climate and Energy
# ExxonMobil's Funding of Climate Science Denial
# Federalist Society
# Foundation for Accountability and Civic Trust (FACT)
# Foundation for Economic Education
# Franklin Center for Government and Public Integrity
# Fraser Institute
# Free Market Environmental Law Clinic
# Free Speech in Science Project
# Free to Choose Network
# Freedom Foundation of Minnesota
# FreedomWorks
# Friends of Science
# Frontier Centre for Public Policy
# Frontiers of Freedom
# FTI Consulting
# Fueling US Forward
# Generation Opportunity
# George C. Marshall Institute
# George Mason University
# Global Climate Coalition
# Global Warming Policy Foundation
# Government Accountability and Oversight
# Greening Earth Society
# Heartland Institute
# Heidelberg Appeal
# Heritage Foundation
# High Park Group
# Hoover Institution on War, Revolution and Peace
# Hudson Institute
# i360
# IceAgeNow
# Illinois Coal Association
# Illinois Policy Institute
# In Pursuit Of
# Independence Institute
# Independent Committee on Geoethics
# Independent Institute
# Independent Women's Forum
# Information Council for the Environment
# Institute for Energy Research
# Institute for Free Enterprise
# Institute for Free Speech
# Institute for Humane Studies
# Institute for Liberty
# Institute for Private Enterprise
# Institute of Economic Affairs
# Institute of Public Affairs
# Instituto Juan de Mariana
# Instituto Liberdade
# Intermountain Rural Electric Association
# International Climate and Environmental Change Assessment Project
# International Climate Science Coalition
# International Policy Network
# Irish Climate Science Forum
# James Madison Institute
# John Birch Society
# John Locke Foundation
# Judicial Crisis Network
# JunkScience.com
# Knowledge and Progress Fund
# Koch Family Foundations
# Koch Industries, Inc.
# Koch Industries, Inc. Lobbying Activities
# Lavoisier Group
# Leadership Institute
# Legatum Institute
# Lexington Institute
# Liberty Institute
# Mackinac Center for Public Policy
# Manhattan Institute for Policy Research
# Manufacturers' Accountability Project
# Media Research Center
# Mercatus Center
# Mercer Family Foundation
# Modern Miracle Network
# Mont Pelerin Society
# Murray Energy
# National Association of Manufacturers
# National Black Chamber of Commerce
# National Center for Policy Analysis
# National Center for Public Policy Research
# National Chicken Council
# National Mining Association
# National Pork Producers Council
# Natural Resources Stewardship Project
# NERA Economic Consulting
# Nevada Policy Research Institute
# New Hope Environmental Services
# New Zealand Climate Science Coalition
# Oil and Gas Climate Initiative
# Oregon Institute of Science and Medicine
# Oregon Petition
# Pacific Research Institute
# Partnership for Energy Progress
# Philanthropy Roundtable
# Politeia
# Power the Future
# PragerU
# Principia Scientific International
# Property and Environment Research Center
# Reaching America
# Reason Foundation
# Renewable Energy Foundation
# Scaife Family Foundations
# Science and Environmental Policy Project
# Science and Public Policy Institute
# Seminar Network
# Stand Together
# State Policy Network
# Statistical Assessment Service
# Talent Market
# TaxPayers' Alliance
# Tech Central Station
# Texas Public Policy Foundation
# The Advancement of Sound Science Coalition
# The Daily Caller
# The Empowerment Alliance
# The Galileo Movement
# Third Energy
# Thomas Jefferson Institute for Public Policy
# Transportation Fairness Alliance
# Trees of Liberty
# TSAugust
# Turning Point USA
# U.S. Grains Council
# University of Buckingham
# US Chamber of Commerce
# VA-SEEE
# Virginia Institute for Public Policy
# Washington Coal Club
# Washington Legal Foundation
# Washington Policy Center
# Western Fuels Association
# Western States Petroleum Association
# World Climate Report
# Your Energy America

# %%
#Functions to retrieve google news articles from search terms and input range and extract full article text

def get_google_news(terms, date_range = ['01/01/1990' , '01/01/2020'], npages = 1):
    """
    Extract google news article search data (title, media, date, datetime, link, desc)
    
    terms: google news search input terms (str)
    date_range: range of dates the search needs to cover [start_date, end_date] 
    npages: number of return pages to search for (int)
    
    returns: list of dictionaries. One dict for each search results
    """
    # Define search terms
    # Should look at 1984 to start
    googlenews = GoogleNews(start =date_range[0] , end = date_range[1])
    googlenews.search(terms)

    # Get results for first 20 pages
    results = []
    for i in range(npages):
        googlenews.getpage(i)
        result = googlenews.result()
        results.append(result)

    results_flat = [item for sublist in results for item in sublist]
    return results_flat

def get_result_data(results):
    """
    Extracts article text, author and date from google news search result
    
    results: list of dictionaries. One dict for each search results
    
    returns: articles, dictionary of articles with keys: authors, year, text, link
    
    Notes: 
    - authors doesn't work well
    - the length of the output dictionary can be shorter than the input search results because links are often dead and 
    the article cannot be retrieved    
    - article text can be hidden by paywall
    """
    articles = []
    for n, art in enumerate(results):
        dico = {}
        dico['media'] = art['media']
        article = Article(art['link'])

        try:

            article.download()
            article.parse()
            dico['authors'] = article.authors
            try:
                dico['year'] = article.publish_date
            except:
                #print(article.publish_date)
                dico['year']=None
            dico['text'] = article.text
            #article.nlp()
            #dico['keywords'] = article.keywords
            #dico['summary'] = article.summary
            dico['link'] = art['link']
            articles.append(dico)
        except:
            #print(art['media'] + ' failed')
            pass
    return articles

def process_google_news(terms, date_range = ['01/01/1990' , '01/01/2020'], npages = 1, search_terms = None):
    """Webscrapes google news and returns full texts, authors, publication years and links
    
    terms: google news search input terms (str)
    date_range: range of dates the search needs to cover [start_date, end_date] 
    npages: number of result pages to scrape (int)
    
    returns: articles, dictionary of articles with keys: authors, year, text, link
    
    Notes: 
    - authors doesn't work well
    - the length of the output dictionary can be shorter than the input search results because links are often dead and 
    the article cannot be retrieved    
    - article text can be hidden by paywall
    """
    
    search_results = get_google_news(terms, date_range, npages)

    articles = get_result_data(search_results)
    if search_terms:
        for art in articles:
            art['search_terms'] = terms
    
    return articles

# %%
# Define search terms as ' "[INSTITUTION NAME]" "climate change" '
search_terms = ['"%s" "climate change"' %i for i in institutions ]

# %%
len(search_terms)
# Out:
# 235

# %%
from datetime import date
import time

# Get current date to define search date range
today = date.today()
current_date = today.strftime('%d/%m/%Y')
print(current_date)

date_range = ['01/01/1990', current_date]
npages = 1

#data = [process_google_news(terms, date_range, npages) for terms in search_terms]
data = []
for terms in search_terms:
    time.sleep(90+30*random.uniform(0, 1))
    print(terms)
    results = process_google_news(terms, date_range, npages, terms)
    data.append(results)
    
    #if not results:
    #    break
# Out:
# 18/01/2021
# "55 Tufton Street" "climate change"
# "60 Plus Association" "climate change"
# "Accuracy in Media" "climate change"
# "Acton Institute" "climate change"
# "Adam Smith Institute" "climate change"
# "Aegis Strategic" "climate change"
# "Africa Fighting Malaria" "climate change"
# "African Centre for Advocacy and Human Development" "climate change"
# "Alberta Prosperity Fund" "climate change"
# "Alexis de Tocqueville Institution" "climate change"
# "Alternate Solutions Institute" "climate change"
# "America Rising LLC | PAC | America Rising Squared | Definers Public Affairs" "climate change"
# "American Association of Blacks in Energy" "climate change"
# "American Chemistry Council" "climate change"
# "American Coalition for Clean Coal Electricity" "climate change"
# "American Commitment" "climate change"
# "American Conservative Union" "climate change"
# "American Council for Capital Formation" "climate change"
# "American Council on Science and Health" "climate change"
# "American Encore" "climate change"
# "American Energy Alliance (AEA)" "climate change"
# "American Enterprise Institute" "climate change"
# "American Fuel & Petrochemical Manufacturers (AFPM) " "climate change"
# "American Future Fund" "climate change"
# "American Institute for Economic Research" "climate change"
# "American Legislative Exchange Council (ALEC)" "climate change"
# "American Petroleum Institute" "climate change"
# "American Tradition Institute" "climate change"
# "Americans for Balanced Energy Choices" "climate change"
# "Americans for Prosperity" "climate change"
# "Americans for Tax Reform" "climate change"
# "Annapolis Center for Science-Based Public Policy" "climate change"
# "APCO Worldwide" "climate change"
# "Atlantic Legal Foundation " "climate change"
# "Atlas Network" "climate change"
# "Australian APEC Study Centre" "climate change"
# "Australian Climate Science Coalition " "climate change"
# "Australian Environment Foundation" "climate change"
# "Australian Libertarian Society" "climate change"
# "Australian Taxpayers' Alliance" "climate change"
# "Austrian Economics Center" "climate change"
# "Ayn Rand Institute" "climate change"
# "Beacon Center of Tennessee" "climate change"
# "Beacon Hill Institute" "climate change"
# "Bill of Rights Institute" "climate change"
# "Burn More Coal" "climate change"
# "Californians for Affordable & Reliable Energy (CARE)" "climate change"
# "Cambridge Analytica" "climate change"
# "Canada Action" "climate change"
# "Canadian Association of Petroleum Producers (CAPP)" "climate change"
# "Capital Research Center" "climate change"
# "Carbon Sense Coalition" "climate change"
# "Cascade Policy Institute " "climate change"
# "Cato Institute" "climate change"
# "Center for Accountability in Science" "climate change"
# "Center for Energy and Economic Development " "climate change"
# "Center for Industrial Progress" "climate change"
# "Center for Liquefied Natural Gas (CLNG)" "climate change"
# "Center for Organizational Research and Education (CORE)" "climate change"
# "Center for the Defense of Free Enterprise" "climate change"
# "Center for the Study of Carbon Dioxide and Global Change" "climate change"
# "Center of the American Experiment" "climate change"
# "Citizens for the Republic" "climate change"
# "Citizens' Alliance for Responsible Energy" "climate change"
# "Civil Society Coalition on Climate Change" "climate change"
# "Clear Energy Alliance" "climate change"
# "Clexit" "climate change"
# "Climate Intelligence Foundation (CLINTEL)" "climate change"
# "Climate Study Group" "climate change"
# "CO2 Coalition" "climate change"
# "Coalition for Regulatory Innovation" "climate change"
# "Coalition to Protect Patients' Rights" "climate change"
# "Committee for a Constructive Tomorrow (CFACT)" "climate change"
# "Competitive Enterprise Institute" "climate change"
# "Concerned Veterans for America" "climate change"
# "Congress of Racial Equality (CORE)" "climate change"
# "Consumer Action for a Strong Economy" "climate change"
# "Consumer Choice Center" "climate change"
# "Consumer Energy Alliance (CEA)" "climate change"
# "Cooler Heads Coalition" "climate change"
# "Copenhagen Consensus Center" "climate change"
# "Cornwall Alliance for the Stewardship of Creation " "climate change"
# "Council for a Competitive Economy" "climate change"
# "CRC Advisors" "climate change"
# "D. James Kennedy Ministries" "climate change"
# "DCI Group" "climate change"
# "Discovery Institute" "climate change"
# "Doctors for Disaster Preparedness" "climate change"
# "Donors Capital Fund" "climate change"
# "Donors Trust " "climate change"
# "Dunn's Foundation for the Advancement of Right Thinking" "climate change"
# "Edison Electric Institute" "climate change"
# "Energy & Environment Legal Institute" "climate change"
# "Energy and Environment (Journal)" "climate change"
# "Energy Equality Coalition" "climate change"
# "Energy In Depth" "climate change"
# "Energy4US" "climate change"
# "Ethical Oil Institute" "climate change"
# "European Institute for Climate and Energy" "climate change"
# "ExxonMobil's Funding of Climate Science Denial" "climate change"
# "Federalist Society" "climate change"
# "Foundation for Accountability and Civic Trust (FACT)" "climate change"
# "Foundation for Economic Education" "climate change"
# "Franklin Center for Government and Public Integrity" "climate change"
# "Fraser Institute" "climate change"
# "Free Market Environmental Law Clinic" "climate change"
# "Free Speech in Science Project" "climate change"
# "Free to Choose Network" "climate change"
# "Freedom Foundation of Minnesota" "climate change"
# "FreedomWorks" "climate change"
# "Friends of Science" "climate change"
# "Frontier Centre for Public Policy " "climate change"
# "Frontiers of Freedom" "climate change"
# "FTI Consulting" "climate change"
# "Fueling US Forward" "climate change"
# "Generation Opportunity" "climate change"
# "George C. Marshall Institute" "climate change"
# "George Mason University" "climate change"
# "Global Climate Coalition" "climate change"
# "Global Warming Policy Foundation " "climate change"
# "Government Accountability and Oversight" "climate change"
# "Greening Earth Society" "climate change"
# "Heartland Institute" "climate change"
# "Heidelberg Appeal" "climate change"
# "Heritage Foundation" "climate change"
# "High Park Group" "climate change"
# "Hoover Institution on War, Revolution and Peace" "climate change"
# "Hudson Institute " "climate change"
# "i360" "climate change"
# "IceAgeNow" "climate change"
# "Illinois Coal Association" "climate change"
# "Illinois Policy Institute" "climate change"
# "In Pursuit Of" "climate change"
# "Independence Institute" "climate change"
# "Independent Committee on Geoethics" "climate change"
# "Independent Institute" "climate change"
# "Independent Women's Forum" "climate change"
# "Information Council for the Environment" "climate change"
# "Institute for Energy Research" "climate change"
# "Institute for Free Enterprise" "climate change"
# "Institute for Free Speech" "climate change"
# "Institute for Humane Studies" "climate change"
# "Institute for Liberty" "climate change"
# "Institute for Private Enterprise" "climate change"
# "Institute of Economic Affairs" "climate change"
# "Institute of Public Affairs" "climate change"
# "Instituto Juan de Mariana" "climate change"
# "Instituto Liberdade" "climate change"
# "Intermountain Rural Electric Association" "climate change"
# "International Climate and Environmental Change Assessment Project" "climate change"
# "International Climate Science Coalition " "climate change"
# "International Policy Network" "climate change"
# "Irish Climate Science Forum" "climate change"
# "James Madison Institute" "climate change"
# "John Birch Society" "climate change"
# "John Locke Foundation" "climate change"
# "Judicial Crisis Network" "climate change"
# "JunkScience.com" "climate change"
# "Knowledge and Progress Fund" "climate change"
# "Koch Family Foundations" "climate change"
# "Koch Industries, Inc. " "climate change"
# "Koch Industries, Inc. Lobbying Activities" "climate change"
# "Lavoisier Group" "climate change"
# "Leadership Institute" "climate change"
# "Legatum Institute" "climate change"
# "Lexington Institute" "climate change"
# "Liberty Institute" "climate change"
# "Mackinac Center for Public Policy" "climate change"
# "Manhattan Institute for Policy Research" "climate change"
# "Manufacturers' Accountability Project" "climate change"
# "Media Research Center" "climate change"
# "Mercatus Center" "climate change"
# "Mercer Family Foundation" "climate change"
# "Modern Miracle Network" "climate change"
# "Mont Pelerin Society" "climate change"
# "Murray Energy" "climate change"
# "National Association of Manufacturers" "climate change"
# "National Black Chamber of Commerce" "climate change"
# "National Center for Policy Analysis" "climate change"
# "National Center for Public Policy Research" "climate change"
# "National Chicken Council" "climate change"
# "National Mining Association" "climate change"
# "National Pork Producers Council" "climate change"
# "Natural Resources Stewardship Project" "climate change"
# "NERA Economic Consulting" "climate change"
# "Nevada Policy Research Institute" "climate change"
# "New Hope Environmental Services" "climate change"
# "New Zealand Climate Science Coalition" "climate change"
# "Oil and Gas Climate Initiative" "climate change"
# "Oregon Institute of Science and Medicine" "climate change"
# "Oregon Petition" "climate change"
# "Pacific Research Institute" "climate change"
# "Partnership for Energy Progress" "climate change"
# "Philanthropy Roundtable" "climate change"
# "Politeia" "climate change"
# "Power the Future" "climate change"
# "PragerU" "climate change"
# "Principia Scientific International" "climate change"
# "Property and Environment Research Center" "climate change"
# "Reaching America" "climate change"
# "Reason Foundation" "climate change"
# "Renewable Energy Foundation" "climate change"
# "Scaife Family Foundations" "climate change"
# "Science and Environmental Policy Project" "climate change"
# "Science and Public Policy Institute" "climate change"
# "Seminar Network" "climate change"
# "Stand Together" "climate change"
# "State Policy Network" "climate change"
# "Statistical Assessment Service" "climate change"
# "Talent Market" "climate change"
# "TaxPayers' Alliance" "climate change"
# "Tech Central Station" "climate change"
# "Texas Public Policy Foundation" "climate change"
# "The Advancement of Sound Science Coalition" "climate change"
# "The Daily Caller" "climate change"
# "The Empowerment Alliance" "climate change"
# "The Galileo Movement" "climate change"
# "Third Energy" "climate change"
# "Thomas Jefferson Institute for Public Policy" "climate change"
# "Transportation Fairness Alliance" "climate change"
# "Trees of Liberty" "climate change"
# "TSAugust" "climate change"
# "Turning Point USA" "climate change"
# "U.S. Grains Council" "climate change"
# "University of Buckingham" "climate change"
# "US Chamber of Commerce" "climate change"
# "VA-SEEE" "climate change"
# "Virginia Institute for Public Policy" "climate change"
# "Washington Coal Club" "climate change"
# "Washington Legal Foundation" "climate change"
# "Washington Policy Center" "climate change"
# "Western Fuels Association" "climate change"
# "Western States Petroleum Association" "climate change"
# "World Climate Report" "climate change"
# "Your Energy America" "climate change"

# %%
data_flat = np.concatenate(data) #np.array(data).flatten()

#merge the dictionaries for individual articles into one
big_dict = {}
for k in data_flat[0].keys():
    big_dict[k] = [d[k] for d in data_flat]
    
    
df = pd.DataFrame(big_dict).astype(str)
df.to_excel('denier_inst_articles_withMedia.xlsx')

# %%
df
# Out:
#                                               authors  \
# 0   ['Byline Times', 'Https', 'Bylinetimes.Com', '...
# 1   ['Byline Times', 'Https', 'Bylinetimes.Com', '...
# 2                                  ['Jessica Murray']
# 3                     ['Sian Cain', 'Jessica Murray']
# 4                                                  []
# 5                                   ['Max Wakefield']
# 6                                                  []
# 7                                                  []
# 8                                                  []
# 9   ['Byline Times', 'Https', 'Bylinetimes.Com', '...
# 10  ['Byline Times', 'Https', 'Bylinetimes.Com', '...
# 11                                 ['Jessica Murray']
# 12                    ['Sian Cain', 'Jessica Murray']
# 13                                                 []
# 14                                  ['Max Wakefield']
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20  ['Union Of Concerned Scientists', 'The Revelat...
# 21                              ['Posted Itai Vardi']
# 22  ['The Christian Science Monitor', 'Bamzi Banch...
# 23                            ['Posted Kelly Roache']
# 24                                                 []
# 25                                                 []
# 26                            ['Posted Kelly Roache']
# 27                 ['Viveca Novak', 'Robert Maguire']
# 28                                                 []
# 29                                                 []
# 30  ['Union Of Concerned Scientists', 'The Revelat...
# 31  ['The Christian Science Monitor', 'Bamzi Banch...
# 32                            ['Posted Kelly Roache']
# 33                                                 []
# 34                                                 []
# 35                            ['Posted Kelly Roache']
# 36                 ['Viveca Novak', 'Robert Maguire']
#
#                          year  \
# 0         2020-09-03 00:00:00
# 1         2020-09-08 00:00:00
# 2         2020-09-02 00:00:00
# 3         2020-09-02 00:00:00
# 4   2016-02-10 21:10:53+00:00
# 5         2020-03-03 00:00:00
# 6                        None
# 7   2020-09-03 13:49:46+01:00
# 8                        None
# 9         2020-09-03 00:00:00
# 10        2020-09-08 00:00:00
# 11        2020-09-02 00:00:00
# 12        2020-09-02 00:00:00
# 13  2016-02-10 21:10:53+00:00
# 14        2020-03-03 00:00:00
# 15                       None
# 16  2020-09-03 13:49:46+01:00
# 17                       None
# 18        2016-06-13 00:00:00
# 19                       None
# 20  2017-01-30 16:21:45+00:00
# 21  2020-09-25 15:49:45+00:00
# 22  2016-03-12 12:42:00-05:00
# 23  2020-02-14 04:08:43+00:00
# 24                       None
# 25        2019-11-19 00:00:00
# 26  2020-05-05 23:08:27+00:00
# 27  2012-03-05 17:08:29+00:00
# 28        2016-06-13 00:00:00
# 29                       None
# 30  2017-01-30 16:21:45+00:00
# 31  2016-03-12 12:42:00-05:00
# 32  2020-02-14 04:08:43+00:00
# 33                       None
# 34        2019-11-19 00:00:00
# 35  2020-05-05 23:08:27+00:00
# 36  2012-03-05 17:08:29+00:00
#
#                                                  text  \
# 0   Rupert Read spent last night in the cells, aft...
# 1   Stephen Colegrave talks to co-founder of the W...
# 2   A number of famous novelists, poets and playwr...
# 3   A group of artists and writers including Zadie...
# 4   Tucked away on the side streets of Westminster...
# 5   On Monday, the government did something remark...
# 6   55 Tufton Street, where many of the meetings t...
# 7   EXTINCTION REBELLION (XR) activists glued them...
# 8   Tufton Street network\n\nWhen Theresa May anno...
# 9   Rupert Read spent last night in the cells, aft...
# 10  Stephen Colegrave talks to co-founder of the W...
# 11  A number of famous novelists, poets and playwr...
# 12  A group of artists and writers including Zadie...
# 13  Tucked away on the side streets of Westminster...
# 14  On Monday, the government did something remark...
# 15  55 Tufton Street, where many of the meetings t...
# 16  EXTINCTION REBELLION (XR) activists glued them...
# 17  Tufton Street network\n\nWhen Theresa May anno...
# 18  Peabody Energy, the world’s largest private-se...
# 19  The YouTube video encourages “real Americans” ...
# 20  By Elliott Negin\n\nThe two dozen nonprofit gr...
# 21  A tangled web of individuals and groups repres...
# 22  Oregon aims to phase out the the reliance on c...
# 23  Dominion Energy debuted on Tuesday a new “net-...
# 24  60 Plus Association is a front group funded by...
# 25  Why did this happen?\n\nPlease make sure your ...
# 26  Key Points:\n\nDuke Energy released a new clim...
# 27  This is the third story in an exclusive series...
# 28  Peabody Energy, the world’s largest private-se...
# 29  The YouTube video encourages “real Americans” ...
# 30  By Elliott Negin\n\nThe two dozen nonprofit gr...
# 31  Oregon aims to phase out the the reliance on c...
# 32  Dominion Energy debuted on Tuesday a new “net-...
# 33  60 Plus Association is a front group funded by...
# 34  Why did this happen?\n\nPlease make sure your ...
# 35  Key Points:\n\nDuke Energy released a new clim...
# 36  This is the third story in an exclusive series...
#
#                                                  link  \
# 0   https://bylinetimes.com/2020/09/03/why-i-was-w...
# 1   https://bylinetimes.com/2020/09/08/tufton-stre...
# 2   https://www.theguardian.com/environment/2020/s...
# 3   https://www.theguardian.com/environment/2020/s...
# 4   https://www.independent.co.uk/news/uk/politics...
# 5   https://www.theguardian.com/commentisfree/2020...
# 6   https://www.opendemocracy.net/en/dark-money-in...
# 7   https://morningstaronline.co.uk/article/b/xr-a...
# 8   https://www.opendemocracy.net/en/opendemocracy...
# 9   https://bylinetimes.com/2020/09/03/why-i-was-w...
# 10  https://bylinetimes.com/2020/09/08/tufton-stre...
# 11  https://www.theguardian.com/environment/2020/s...
# 12  https://www.theguardian.com/environment/2020/s...
# 13  https://www.independent.co.uk/news/uk/politics...
# 14  https://www.theguardian.com/commentisfree/2020...
# 15  https://www.opendemocracy.net/en/dark-money-in...
# 16  https://morningstaronline.co.uk/article/b/xr-a...
# 17  https://www.opendemocracy.net/en/opendemocracy...
# 18  https://www.prwatch.org/news/2016/06/13114/pea...
# 19  https://news.bloomberglaw.com/securities-law/s...
# 20  https://www.ecowatch.com/koch-brothers-pruitt-...
# 21  https://www.energyandpolicy.org/in-pennsylvani...
# 22  https://www.csmonitor.com/Environment/2016/031...
# 23  https://www.energyandpolicy.org/dominion-net-z...
# 24  https://www.energyandpolicy.org/60-plus-associ...
# 25  https://www.bloomberg.com/news/articles/2019-1...
# 26  https://www.energyandpolicy.org/duke-2020-clim...
# 27  https://www.opensecrets.org/news/2012/03/energ...
# 28  https://www.prwatch.org/news/2016/06/13114/pea...
# 29  https://news.bloomberglaw.com/securities-law/s...
# 30  https://www.ecowatch.com/koch-brothers-pruitt-...
# 31  https://www.csmonitor.com/Environment/2016/031...
# 32  https://www.energyandpolicy.org/dominion-net-z...
# 33  https://www.energyandpolicy.org/60-plus-associ...
# 34  https://www.bloomberg.com/news/articles/2019-1...
# 35  https://www.energyandpolicy.org/duke-2020-clim...
# 36  https://www.opensecrets.org/news/2012/03/energ...
#
#                               search_terms
# 0      "55 Tufton Street" "climate change"
# 1      "55 Tufton Street" "climate change"
# 2      "55 Tufton Street" "climate change"
# 3      "55 Tufton Street" "climate change"
# 4      "55 Tufton Street" "climate change"
# 5      "55 Tufton Street" "climate change"
# 6      "55 Tufton Street" "climate change"
# 7      "55 Tufton Street" "climate change"
# 8      "55 Tufton Street" "climate change"
# 9      "55 Tufton Street" "climate change"
# 10     "55 Tufton Street" "climate change"
# 11     "55 Tufton Street" "climate change"
# 12     "55 Tufton Street" "climate change"
# 13     "55 Tufton Street" "climate change"
# 14     "55 Tufton Street" "climate change"
# 15     "55 Tufton Street" "climate change"
# 16     "55 Tufton Street" "climate change"
# 17     "55 Tufton Street" "climate change"
# 18  "60 Plus Association" "climate change"
# 19  "60 Plus Association" "climate change"
# 20  "60 Plus Association" "climate change"
# 21  "60 Plus Association" "climate change"
# 22  "60 Plus Association" "climate change"
# 23  "60 Plus Association" "climate change"
# 24  "60 Plus Association" "climate change"
# 25  "60 Plus Association" "climate change"
# 26  "60 Plus Association" "climate change"
# 27  "60 Plus Association" "climate change"
# 28  "60 Plus Association" "climate change"
# 29  "60 Plus Association" "climate change"
# 30  "60 Plus Association" "climate change"
# 31  "60 Plus Association" "climate change"
# 32  "60 Plus Association" "climate change"
# 33  "60 Plus Association" "climate change"
# 34  "60 Plus Association" "climate change"
# 35  "60 Plus Association" "climate change"
# 36  "60 Plus Association" "climate change"
